# %%
import pandas as pd
import numpy as np
import re
import string
from spellchecker import SpellChecker

# %%
df = pd.read_csv('train.csv', encoding='ISO-8859-1')

# %%
df['target'] = df['target'].astype(np.uint8)
df.set_index('id', inplace = True)

# %%
df.sample(10, random_state=42)
# Out:
#           keyword               location  \
# id
# 3796  destruction                    NaN
# 3185       deluge                    NaN
# 7769       police                     UK
# 191    aftershock                    NaN
# 9810       trauma  Montgomery County, MD
# 7934    rainstorm                    NaN
# 2538    collision                    NaN
# 2611      crashed                    NaN
# 9756      tragedy        Los Angeles, CA
# 6254    hijacking          Athens,Greece
#
#                                                    text  target
# id
# 3796  So you have a new weapon that can cause un-ima...       1
# 3185  The f$&amp;@ing things I do for #GISHWHES Just...       0
# 7769  DT @georgegalloway: RT @Galloway4Mayor: ÂÃÃ...       1
# 191   Aftershock back to school kick off was great. ...       0
# 9810  in response to trauma Children of Addicts deve...       0
# 7934  @Calum5SOS you look like you got caught in a r...       0
# 2538  my favorite lady came to our volunteer meeting...       1
# 2611  @brianroemmele UX fail of EMV - people want to...       1
# 9756  Can't find my ariana grande shirt  this is a f...       0
# 6254  The Murderous Story Of AmericaÂÃÂªs First Hi...       1

# %%
sentence = df.loc[6254, 'text']
sentence
# Out:
# 'The Murderous Story Of AmericaÂ\x89Ã\x9bÂªs First Hijacking http://t.co/EYUGk6byxr'

# %% [markdown]
# ### Cosas a tener en cuenta.
# - La columna `id` puede no ser indicativa de nada para la predicción. Puede ser conveniente usarlo como índice;
# - Hay 7613 casos en el train, si se quitan los nulos en `keyword` solo quedan los nulos en `location` y no se superponen.

# %%
# Función para limpiar el texto de los mensajes.
def clean_text(text):
    # Se convierte el texto a minúsculas.
    text = text.lower()
    # Se quitan los '#'.
    text = re.sub('#', '', text)
    # Se quitan los números.
    text = re.sub('\w*\d\w*', '', text)
    # Se quitan las llaves y atributos de html.
    text = re.sub(r'<.*?>', '', text)
    # Se quitan los saltos de línea.
    text = re.sub('\n', ' ', text)
    # Se eliminan las referencias a usuarios '@user'.
    text = re.sub('@\S*', '', text)
    # Se quitan vínculos URL.
    text = re.sub(r'https?://\S+|www\.\S+', ' ', text)
    # Se simplifican múltiples espacios a uno solo.
    text = re.sub('(\ ){2,7}', ' ',text)
    # Se quitan los signos de puntuación.
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    # Se quitan los caracteres no ASCII
    text = re.sub(r'[^\x00-\x7F]+','ñ', text)
    return text

df['text'] = df['text'].apply(lambda x: clean_text(x))

#======= MUESTRA ALEATORIA =======
# Se elige un ancho para la visualización de columnas
pd.set_option('max_colwidth', 150)

display(df.sample(10, random_state=42))
# Out:
#           keyword               location  \
# id
# 3796  destruction                    NaN
# 3185       deluge                    NaN
# 7769       police                     UK
# 191    aftershock                    NaN
# 9810       trauma  Montgomery County, MD
# 7934    rainstorm                    NaN
# 2538    collision                    NaN
# 2611      crashed                    NaN
# 9756      tragedy        Los Angeles, CA
# 6254    hijacking          Athens,Greece
#
#                                                                                                                           text  \
# id
# 3796                                                          so you have a new weapon that can cause unimaginable destruction
# 3185                             the famp things i do for gishwhes just got soaked in a deluge going for pads and tampons thx
# 7769                                                          dt rt ñthe col police can catch a pickpocket in liverpool stree
# 191            aftershock back to school kick off was great i want to thank everyone for making it possible what a great night
# 9810                      in response to trauma children of addicts develop a defensive self one that decreases vulnerability
# 7934                               you look like you got caught in a rainstorm this is amazing and disgusting at the same time
# 2538                     my favorite lady came to our volunteer meeting hopefully joining her youth collision and i am excite
# 2611   ux fail of emv people want to insert and remove quickly like a gas pump stripe reader person told me it crashed the pos
# 9756                                                                cant find my ariana grande shirt this is a fucking tragedy
# 6254                                                                         the murderous story of americañs first hijacking
#
#       target
# id
# 3796       1
# 3185       0
# 7769       1
# 191        0
# 9810       0
# 7934       0
# 2538       1
# 2611       1
# 9756       0
# 6254       1

# %% [markdown]
# ### Se corrigen las palabras

# %%
corrector = SpellChecker()

# Las palabras deben estar en minúscula para que funcione
def corregir_terminos(texto):
    lista_palabras = texto.split()
    corregidos = []
    a_corregir = corrector.unknown(lista_palabras)
    
    for palabra in lista_palabras:
        if palabra in a_corregir:
            corregidos.append(corrector.correction(palabra))
        else:
            corregidos.append(palabra)
    return " ".join(corregidos)

# %%
% time
df['text'] = df['text'].apply(lambda x: corregir_terminos(x))

# %%
df.sample(10, random_state=42)
# Out:
#           keyword               location  \
# id
# 3796  destruction                    NaN
# 3185       deluge                    NaN
# 7769       police                     UK
# 191    aftershock                    NaN
# 9810       trauma  Montgomery County, MD
# 7934    rainstorm                    NaN
# 2538    collision                    NaN
# 2611      crashed                    NaN
# 9756      tragedy        Los Angeles, CA
# 6254    hijacking          Athens,Greece
#
#                                                                                                                         text  \
# id
# 3796                                                        so you have a new weapon that can cause unimaginable destruction
# 3185                            the camp things i do for gishwhes just got soaked in a deluge going for pads and tampons the
# 7769                                                         dt rt the col police can catch a pickpocket in liverpool street
# 191         aftershocks back to school kick off was great i want to thank everyone for making it possible what a great night
# 9810                     in response to trauma children of addicts develop a defensive self one that decreases vulnerability
# 7934                             you look like you got caught in a rainstorm this is amazing and disgusting at the same time
# 2538                    my favorite lady came to our volunteer meeting hopefully joining her youth collision and i am excite
# 2611  ux fail of em people want to insert and remove quickly like a gas pump stripe reader person told me it crashed the pos
# 9756                                                              cant find my ariana grande shirt this is a fucking tragedy
# 6254                                                                        the murderous story of americans first hijacking
#
#       target
# id
# 3796       1
# 3185       0
# 7769       1
# 191        0
# 9810       0
# 7934       0
# 2538       1
# 2611       1
# 9756       0
# 6254       1
